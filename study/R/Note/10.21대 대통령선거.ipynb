# %%
options(warn = -1)
options(repr.plot.width = 15, repr.plot.height = 9)
Sys.setlocale(category = "LC_ALL",locale = "ko_KR.UTF-8")
# Out:
# [1] "ko_KR.UTF-8/ko_KR.UTF-8/ko_KR.UTF-8/C/ko_KR.UTF-8/C.UTF-8"

# %%
vote <- read.csv("../Data/21대_대통령선거.csv", header = T) 
head(data)
# Out:
#
# 1 function (..., list = character(), package = NULL, lib.loc = NULL,
# 2     verbose = getOption("verbose"), envir = .GlobalEnv, overwrite = TRUE)
# 3 {
# 4     fileExt <- function(x) {
# 5         db <- grepl("\\\\.[^.]+\\\\.(gz|bz2|xz)$", x)
# 6         ans <- sub(".*\\\\.", "", x)

# %%
vote_sum <- aggregate(투표수 ~ 광역시도, vote, sum)

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# 내림차순으로 정렬
arrange(vote_sum, desc(투표수))
# Out:
#    광역시도       투표수
# 1  경기도         9297448
# 2  서울특별시     6641606
# 3  부산광역시     2245755
# 4  경상남도       2179989
# 5  인천광역시     2035355
# 6  경상북도       1747364
# 7  대구광역시     1643051
# 8  충청남도       1397521
# 9  전라남도       1303365
# 10 전북특별자치도 1246099
# 11 충청북도       1065558
# 12 강원특별자치도 1029407
# 13 광주광역시     1002149
# 14 대전광역시      977609
# 15 울산광역시      747950
# 16 제주특별자치도  421576
# 17 세종특별자치시  254695

# %%
vote_sum$투표율 <- round((vote_sum$투표수) /sum(vote_sum$투표수) *100, 2)
vote_sum
# Out:
#    광역시도       투표수  투표율
# 1  강원특별자치도 1029407  2.92
# 2  경기도         9297448 26.39
# 3  경상남도       2179989  6.19
# 4  경상북도       1747364  4.96
# 5  광주광역시     1002149  2.84
# 6  대구광역시     1643051  4.66
# 7  대전광역시      977609  2.77
# 8  부산광역시     2245755  6.37
# 9  서울특별시     6641606 18.85
# 10 세종특별자치시  254695  0.72
# 11 울산광역시      747950  2.12
# 12 인천광역시     2035355  5.78
# 13 전라남도       1303365  3.70
# 14 전북특별자치도 1246099  3.54
# 15 제주특별자치도  421576  1.20
# 16 충청남도       1397521  3.97
# 17 충청북도       1065558  3.02

# %%
# 내림차순으로 정렬
vote_sum <- arrange(vote_sum, desc(투표율))

# %%
vote_sum
# Out:
#    광역시도       투표수  투표율
# 1  경기도         9297448 26.39
# 2  서울특별시     6641606 18.85
# 3  부산광역시     2245755  6.37
# 4  경상남도       2179989  6.19
# 5  인천광역시     2035355  5.78
# 6  경상북도       1747364  4.96
# 7  대구광역시     1643051  4.66
# 8  충청남도       1397521  3.97
# 9  전라남도       1303365  3.70
# 10 전북특별자치도 1246099  3.54
# 11 충청북도       1065558  3.02
# 12 강원특별자치도 1029407  2.92
# 13 광주광역시     1002149  2.84
# 14 대전광역시      977609  2.77
# 15 울산광역시      747950  2.12
# 16 제주특별자치도  421576  1.20
# 17 세종특별자치시  254695  0.72

# %%
str(vote)
# Out:
# 'data.frame':	253 obs. of  7 variables:
#  $ 광역시도: chr  "서울특별시" "서울특별시" "서울특별시" "서울특별시" ...
#  $ 시군구  : chr  "종로구" "중구" "용산구" "성동구" ...
#  $ 선거인수: int  125901 110181 183614 244536 301007 307846 342360 374002 257971 272942 ...
#  $ 투표수  : int  99261 87166 143813 196282 239807 246264 267642 300299 198136 216499 ...
#  $ 이재명  : int  47735 40482 58705 88028 114304 117631 137420 152624 105780 110614 ...
#  $ 김문수  : int  39574 36302 67927 84043 94752 97549 102137 111271 72792 84148 ...
#  $ 이준석  : int  9326 8450 13794 20217 25469 25928 22923 29394 15575 17568 ...

# %%
library(plotrix)

# %%
par(family = 'AppleGothic',bg = 'white')


label <- paste(vote_sum$광역시도, "\n", vote_sum$투표율, "%")

pie3D(vote_sum$투표율,
    main = "광역시도별 투표율",
    col = rainbow(length(vote_sum$투표율)),
    labels = label,
    labelcex = 0.7
)
# Out:
# Plot with title “광역시도별 투표율”
