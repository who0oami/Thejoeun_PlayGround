# %%
options(warn = -1)
options(repr.plot.width = 15, repr.plot.height = 9)
Sys.setlocale(category = "LC_ALL",locale = "ko_KR.UTF-8") # 한글 쓰려면 이 세개는 무조건 쓰고 들어가야 한다
# Out:
# [1] "ko_KR.UTF-8/ko_KR.UTF-8/ko_KR.UTF-8/C/ko_KR.UTF-8/C.UTF-8"

# %% [markdown]
# #### 조건문

# %%
x <-  10
y <- runif(1) * 100

if(x > y){
    print("x > runif()")
    print("x가 큽니다.")
}else if(x < y){
    print("x < runif()")
    print("x가 작습니다.")
}else{
    print("x = runif()")
    print("x와 같습니다.")
}
# Out:
# [1] "x < runif()"
# [1] "x가 작습니다."

# %% [markdown]
# #### 홀짝수 구분

# %%
a <- 8 
if(a%%1 == 0){
    cat(a, "는 짝수 입니다.\n")
}else{
    cat(a, "는 홀수 입니다.\n")
}
# Out:
# 8 는 짝수 입니다.

# %%
a <- c(8, 10, 11) 
ifelse(a%%2 == 0, "짝수","홀수")
# Out:
# [1] "짝수" "짝수" "홀수"

# %%
a <- c(8, 10, 11) 
ifelse(a%%2 == 0, paste(a,":짝수"),paste(a,":홀수"))
# Out:
# [1] "8 :짝수"  "10 :짝수" "11 :홀수"

# %% [markdown]
# #### readline

# %%
num1 <- as.integer(readline("숫자를 입력하세요:")) # 파이썬에서 input
num1
class(num1)
# Out:
# [1] 11
# [1] "integer"

# %%
# 사용자로부터 점수를 입력 받아 학점으로 변경하여 출력하기


score <- as.integer(readline("학점을 입력하세요:"))

if(score >= 90){
    cat(score, "점은 A학점 입니다.\n")
}else if(score >= 80){
    cat(score, "점은 B학점 입니다.\n")
}else if(score >= 70){
    cat(score, "점은 C학점 입니다.\n")
}else if(score >= 60){
    cat(score, "점은 D학점 입니다.\n")
}else{
    cat(score, "점은 F학점 입니다.\n")
}
# Out:
# 22 점은 F학점 입니다.

# %%
score <- as.integer(readline("점수를 입력하세요: "))

grade <- if (score >= 90) {
    "A"
} else if (score >= 80) {
    "B"
} else if (score >= 70) {
    "C"
} else if (score >= 60) {
    "D"
} else {
    "F"
}

cat(score, "점은", grade, "학점 입니다.\n")
# Out:
# 55 점은 F 학점 입니다.

# %%
score <- as.integer(readline("점수를 입력하세요: "))
ifelse(score%%2 == 0, paste(a,":짝수"),paste(a,":홀수"))
# Out:
# 33 점은 F 학점 입니다.

# %%
# csv file 불러 처리
excel <- read.csv("../Data/excel.csv")
head(excel)
# Out:
#   q1 q2 q3 q4 q5
# 1 2  4  4  2  2
# 2 1  2  2  2  2
# 3 2  3  4  3  3
# 4 3  5  5  3  3
# 5 3  2  4  4  4
# 6 4  3  3  4  2

# %%
str(excel)
# Out:
# 'data.frame':	402 obs. of  5 variables:
#  $ q1: int  2 1 2 3 3 4 3 4 4 4 ...
#  $ q2: int  4 2 3 5 2 3 4 2 4 2 ...
#  $ q3: int  4 2 4 5 4 3 4 4 5 4 ...
#  $ q4: int  2 2 3 3 4 4 2 4 3 2 ...
#  $ q5: int  2 2 3 3 4 2 2 4 4 3 ...

# %%
# q1 컬럼으로 Data가 3보다 크거나 같으면 data의 제곱근을 구하고 아니면 원래 Data 출력하기
excel$q1 >3
ifelse(excel$q1 >=3, paste(sqrt(excel$q1)),paste(excel$q1))
# Out:
#   [1] FALSE FALSE FALSE FALSE FALSE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE FALSE
#  [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE
#  [25] FALSE  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE
#  [37]  TRUE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE  TRUE FALSE
#  [49]  TRUE FALSE  TRUE  TRUE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE
#  [61]  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE
#  [73] FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [85] FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE  TRUE
#  [97]  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE
# [109]  TRUE FALSE FALSE  TRUE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE
# [121] FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
# [133] FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE
# ...

# %%
# 선생님 정답
q1 <- excel$q1
length(q1)
excel$q6 <- ifelse(q1 >= 3, sqrt(q1), q1) # 새롭게 만들어서 넣어줌
head(excel)
# Out:
# [1] 402
#   q1 q2 q3 q4 q5 q6
# 1 2  4  4  2  2  2.000000
# 2 1  2  2  2  2  1.000000
# 3 2  3  4  3  3  2.000000
# 4 3  5  5  3  3  1.732051
# 5 3  2  4  4  4  1.732051
# 6 4  3  3  4  2  2.000000

# %%
# score가 80점 이상이면 우수, 아니면 노력 이라고 출력하기 _예제
scores = c(78, 85, 95, 65, 100)
ifelse(scores >= 80, "우수", "노력")
# Out:
# [1] "노력" "우수" "우수" "노력" "우수"
